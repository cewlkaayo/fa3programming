# %% [markdown]
# <a href="https://colab.research.google.com/github/cewlkaayo/fa3programming/blob/main/fa3programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ask for sutendent information
name= input("Enter your name")
age= input("Enter your age")
course= input("Enter course")

# display formatted output
print("Student Information⋆‧°𓏲ּ𝄢")
print("Name⋆‧°𓏲ּ𝄢:", name)
print("Age⋆‧°𓏲ּ𝄢:", age)
print("Course⋆‧°𓏲ּ𝄢:", course)
# Out:
# Enter your namejojo siwa
# Enter your ageshannon debussy
# Enter coursecollage
# Student Information⋆‧°𓏲ּ𝄢
# Name⋆‧°𓏲ּ𝄢: jojo siwa
# Age⋆‧°𓏲ּ𝄢: shannon debussy
# Course⋆‧°𓏲ּ𝄢: collage

# %%
# input exam score
score = int(input("Enter exam score"))

#check pass or fail
if score >=75:
   print("passed! good job!")
else:
  print("failed... good luck next time")
# Out:
# Enter exam score67
# failed... good luck next time

# %%
# input student info
name= input("Enter your name")
score= int(input("Enter your score"))

# determine other grade
if score >=90:
  grade= "A!"
elif score >=80:
  grade= "B"
elif score >=70:
  grade="C"
else:
  grade= "F..."

# Display student grade
print(f"{name}, your grade is {grade}")
# Out:
# Enter your nameshannon dubussy
# Enter your score67
# shannon dubussy, your grade is F...
